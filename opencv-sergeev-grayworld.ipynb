# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline 

image_path = 'openCV-data/lena.png'

img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray')

# %%
def grayworld(img):
    from copy import deepcopy
    img = deepcopy(img)
    img = img.astype('float64')

    #т.к. элементы img имеют вид, то, соответственно, первое 
    # значение этого массива - это красный цвет, второе - зелёный, последнее- синий. 
    #array([225, 137, 127], dtype=uint8). считаем среднее значение пикселя каждого из этих цветов. 
    R_mean = np.sum(img[:,:,0]) / (img.shape[0] * img.shape[1])
    G_mean = np.sum(img[:,:,1]) / (img.shape[0] * img.shape[1])
    B_mean = np.sum(img[:,:,2]) / (img.shape[0] * img.shape[1])


    Avg = (R_mean + G_mean + B_mean) / 3.0 #а потом общее среднее

    img[:,:,0] = (img[:,:,0] * Avg / R_mean) #и переписываем значения в исходном изображении
    img[:,:,1] = (img[:,:,1] * Avg / G_mean)
    img[:,:,2] = (img[:,:,2] * Avg / B_mean)

    cv2.normalize(img, img, 0, 255, cv2.NORM_MINMAX)
    img = img.astype(np.uint8)

    return img

# %%
image_path = 'openCV-data/lena.png'
from scipy import misc
img = misc.imread(image_path)
plt.imshow(img)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
img2 = grayworld(img)
plt.imshow(img2)
